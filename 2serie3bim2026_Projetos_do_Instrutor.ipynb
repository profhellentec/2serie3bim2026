# %% [markdown]
# <a href="https://colab.research.google.com/github/profhellentec/2serie3bim2026/blob/main/2serie3bim2026_Projetos_do_Instrutor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
senha = ""

while senha != "123":
    senha = input("Digite a senha: ")

print("Acesso liberado!")

# %%
L1=int(input("Digite o nº de páginas do livro 1: "))

print(L1)

# %%
L1=int(input("Digite o nº de páginas do livro 1: "))

print(L1)
l1,l2,l3
# Out:
# Digite o nº de páginas do livro 1: 20
# 20
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2607/831189622.py in <cell line: 0>()
#       2
#       3 print(L1)
# ----> 4 l1,l2,l3
#
# NameError: name 'l1' is not defined

# %%
5
L1=int(input("Digite o nº de páginas do livro 1: "))
L2=int(input("digite o nº de pagina do livro 2: "))
l3=int(input("digite o nº de pagina do livro 3: "))

maior_numero_de_paginas=max(L1,L2,l3)
print("o livro com maior nº de páginas é:", maior_numero_de_paginas)

# %%
5
L1=int(input("Digite o nº de páginas do livro 1: "))
L2=int(input("digite o nº de pagina do livro 2: "))
l3=int(input("digite o nº de pagina do livro 3: "))

maior_numero_de_paginas=max(L1,L2,l3)
print("o livro com maior nº de páginas é:", maior_numero_de_paginas)
